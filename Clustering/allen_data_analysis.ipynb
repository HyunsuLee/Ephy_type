# %% [markdown]
# # Clustering neuron data
# ## electrophysiology and morpology data from allen brain data portal
#
# ### Purpose of this notebook
# 1. download fresh data from allen data portal.
# 1. exploration the data
#   1. density plot (vs Cre line)
#   1. Box plot (vs Cre line)
# 1. clustering neurons using unsupervised ML methods.
#   1. hierachial tree
#   1. k-nearset
#   1. etc
# 1. comparison clustered neurons and its Cre_line property

# %% [markdown]
# Requirements for this notebook
# * __allensdk__ for python2.7
# * [Reference notebook](http://alleninstitute.github.io/AllenSDK/_static/examples/nb/cell_types.html)

# %%
from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.api.queries.cell_types_api import CellTypesApi
from allensdk.core.cell_types_cache import ReporterStatus as RS
import pandas as pd
# Out:
# /home/hyunsu/anaconda3/envs/allen/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
ctc = CellTypesCache(manifest_file='cell_types/manifest.json')

# %%
# all cells
cells = ctc.get_cells()
print("All cells: %d" % len(cells))
# Out:
# All cells: 1337

# %%
ephys_features = ctc.get_ephys_features()
ef_df = pd.DataFrame(ephys_features)
print(len(ef_df))
ef_df.head()
# Out:
# 1337
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0    0.093021   81.498750       -6.184375         0.205899
# 1    0.064384   76.283333       26.135000         0.195247
# 2         NaN         NaN       -4.600001         0.055443
# 3    0.048709  118.397143      -90.575616         0.307589
# 4    0.042215   81.394545       13.653750         0.162729
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.126905            2.768700                    1.025464
# 1                   1.102660            4.005247                    1.024873
# 2                   1.104820            9.092507                    1.025024
# 3                   1.069770            7.203945                    1.024593
# 4                   1.089750            2.336427                    1.027302
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -51.187504          -50.328125                  -55.312504
# 1                 -48.718750          -49.875001                  -51.500004
# 2                 -48.093750          -49.541669                  -50.312503
# 3                 -45.968754          -49.093754                  -53.800002
# 4                 -48.906250          -51.083335                  -55.800002
#
#      ...     trough_t_ramp trough_t_short_square trough_v_long_square  \
# 0    ...          2.804613              1.333809           -56.531254
# 1    ...          4.005453              1.344913           -48.843754
# 2    ...          9.103360              1.197772           -49.531250
# 3    ...          7.204045              1.233473           -46.156254
# 4    ...          2.361778              1.691744           -52.093750
#
#    trough_v_ramp  trough_v_short_square  \
# 0     -56.812502             -69.306253
# 1     -50.093753             -67.416669
# 2     -49.968753             -75.656255
# 3     -49.218753             -66.318753
# 4     -57.614586             -73.337500
#
#    upstroke_downstroke_ratio_long_square  upstroke_downstroke_ratio_ramp  \
# 0                               3.904747                        4.131130
# 1                               4.231335                        4.299535
# 2                               2.154281                        1.486651
# 3                               2.026000                        1.827572
# 4                               4.208485                        4.274151
#
#    upstroke_downstroke_ratio_short_square  vm_for_sag      vrest
# 0                                3.899439  -85.156258 -68.233376
# 1                                3.939083  -78.593750 -66.085068
# 2                                2.400687  -87.156250 -75.141449
# 3                                1.818158  -82.406250 -65.503044
# 4                                4.096372  -99.093758 -72.174675
#
# [5 rows x 55 columns]

# %%
cell_index = { c['id']: c for c in cells }

# %%
reporter_status = [cell_index[cid]['reporter_status'] for cid in ef_df['specimen_id']]

# %%
tg_line = [cell_index[cid]['transgenic_line'] for cid in ef_df['specimen_id']]

# %%
ef_df['transgenic_line'] = pd.Series(tg_line, index=ef_df.index)
ef_df.head()
# Out:
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0    0.093021   81.498750       -6.184375         0.205899
# 1    0.064384   76.283333       26.135000         0.195247
# 2         NaN         NaN       -4.600001         0.055443
# 3    0.048709  118.397143      -90.575616         0.307589
# 4    0.042215   81.394545       13.653750         0.162729
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.126905            2.768700                    1.025464
# 1                   1.102660            4.005247                    1.024873
# 2                   1.104820            9.092507                    1.025024
# 3                   1.069770            7.203945                    1.024593
# 4                   1.089750            2.336427                    1.027302
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -51.187504          -50.328125                  -55.312504
# 1                 -48.718750          -49.875001                  -51.500004
# 2                 -48.093750          -49.541669                  -50.312503
# 3                 -45.968754          -49.093754                  -53.800002
# 4                 -48.906250          -51.083335                  -55.800002
#
#         ...        trough_t_short_square trough_v_long_square trough_v_ramp  \
# 0       ...                     1.333809           -56.531254    -56.812502
# 1       ...                     1.344913           -48.843754    -50.093753
# 2       ...                     1.197772           -49.531250    -49.968753
# 3       ...                     1.233473           -46.156254    -49.218753
# 4       ...                     1.691744           -52.093750    -57.614586
#
#    trough_v_short_square  upstroke_downstroke_ratio_long_square  \
# 0             -69.306253                               3.904747
# 1             -67.416669                               4.231335
# 2             -75.656255                               2.154281
# 3             -66.318753                               2.026000
# 4             -73.337500                               4.208485
#
#    upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 0                        4.131130                                3.899439
# 1                        4.299535                                3.939083
# 2                        1.486651                                2.400687
# 3                        1.827572                                1.818158
# 4                        4.274151                                4.096372
#
#    vm_for_sag      vrest  transgenic_line
# 0  -85.156258 -68.233376     Cux2-CreERT2
# 1  -78.593750 -66.085068  Chrna2-Cre_OE25
# 2  -87.156250 -75.141449             None
# 3  -82.406250 -65.503044     Sst-IRES-Cre
# 4  -99.093758 -72.174675     Cux2-CreERT2
#
# [5 rows x 56 columns]

# %%
ef_df['reporter_status'] = pd.Series(reporter_status, index=ef_df.index)
ef_df.head()
# Out:
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0    0.093021   81.498750       -6.184375         0.205899
# 1    0.064384   76.283333       26.135000         0.195247
# 2         NaN         NaN       -4.600001         0.055443
# 3    0.048709  118.397143      -90.575616         0.307589
# 4    0.042215   81.394545       13.653750         0.162729
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.126905            2.768700                    1.025464
# 1                   1.102660            4.005247                    1.024873
# 2                   1.104820            9.092507                    1.025024
# 3                   1.069770            7.203945                    1.024593
# 4                   1.089750            2.336427                    1.027302
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -51.187504          -50.328125                  -55.312504
# 1                 -48.718750          -49.875001                  -51.500004
# 2                 -48.093750          -49.541669                  -50.312503
# 3                 -45.968754          -49.093754                  -53.800002
# 4                 -48.906250          -51.083335                  -55.800002
#
#            ...           trough_v_long_square trough_v_ramp  \
# 0          ...                     -56.531254    -56.812502
# 1          ...                     -48.843754    -50.093753
# 2          ...                     -49.531250    -49.968753
# 3          ...                     -46.156254    -49.218753
# 4          ...                     -52.093750    -57.614586
#
#   trough_v_short_square  upstroke_downstroke_ratio_long_square  \
# 0            -69.306253                               3.904747
# 1            -67.416669                               4.231335
# 2            -75.656255                               2.154281
# 3            -66.318753                               2.026000
# 4            -73.337500                               4.208485
#
#    upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 0                        4.131130                                3.899439
# 1                        4.299535                                3.939083
# 2                        1.486651                                2.400687
# 3                        1.827572                                1.818158
# 4                        4.274151                                4.096372
#
#    vm_for_sag      vrest  transgenic_line        reporter_status
# 0  -85.156258 -68.233376     Cux2-CreERT2  cre reporter negative
# 1  -78.593750 -66.085068  Chrna2-Cre_OE25  cre reporter positive
# 2  -87.156250 -75.141449             None         not applicable
# 3  -82.406250 -65.503044     Sst-IRES-Cre  cre reporter positive
# 4  -99.093758 -72.174675     Cux2-CreERT2  cre reporter positive
#
# [5 rows x 57 columns]

# %%
ef_df_cre = ef_df[ef_df['reporter_status']=='cre reporter positive']
len(ef_df_cre)
# Out:
# 969

# %%
ef_df_cre.to_csv('ephys_data_cre.csv', index = False)
