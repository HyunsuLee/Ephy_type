# %% [markdown]
# # Allen brain institue Data Analysis
# ## Electrophysiology & morphology data
#
# 1. PCA analysis
# 2. spiny vs aspiny
# 3. Excitatory vs inhibitory - Cre mice line and cre reporter positive negative check!!

# %%
# %matplotlib inline

import numpy as np
from sklearn.decomposition import PCA
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale

# %%
data = pd.read_csv('cell_data.csv')

# %%
data.head()
# Out:
#          line_name  specimen__id                         specimen__name  \
# 0   Scnn1a-Tg2-Cre     313862022    Scnn1a-Tg2-Cre;Ai14-167081.03.02.01
# 1   Rorb-IRES2-Cre     479508018  Rorb-IRES2-Cre-D;Ai14-196662.03.01.01
# 2  Htr3a-Cre_NO152     442627661   Htr3a-Cre_NO152;Ai14-178904.06.01.01
# 3     Cux2-CreERT2     487358945      Cux2-CreERT2;Ai14-214155.05.01.01
# 4   Scnn1a-Tg3-Cre     469803127    Scnn1a-Tg3-Cre;Ai14-180215.05.02.01
#
#   specimen__hemisphere  structure__id               structure__name  \
# 0                right            721  Primary visual area, layer 4
# 1                 left            721  Primary visual area, layer 4
# 2                 left      312782566       Anterior area, layer 6a
# 3                 left            778  Primary visual area, layer 5
# 4                right            778  Primary visual area, layer 5
#
#   structure__acronym  structure_parent__id structure_parent__acronym  \
# 0              VISp4                   385                      VISp
# 1              VISp4                   385                      VISp
# 2             VISa6a             312782546                      VISa
# 3              VISp5                   385                      VISp
# 4              VISp5                   385                      VISp
#
#   structure__layer ...    cell_reporter_status  m__glif  \
# 0                4 ...   cre reporter positive        0
# 1                4 ...   cre reporter positive        2
# 2               6a ...   cre reporter positive        0
# 3                5 ...   cre reporter positive        5
# 4                5 ...   cre reporter positive        5
#
#    m__biophys_perisomatic  m__biophys_all_active  tag__apical  \
# 0                       1                      0       intact
# 1                       0                      0       intact
# 2                       0                      0          NaN
# 3                       0                      0       intact
# 4                       0                      0       intact
#
#    tag__dendrite_type                            morph_thumb_path  \
# 0               spiny  /api/v2/well_known_file_download/487659609
# 1               spiny                                         NaN
# 2              aspiny                                         NaN
# 3               spiny                                         NaN
# 4               spiny                                         NaN
#
#                              ephys_thumb_path  \
# 0  /api/v2/well_known_file_download/487623088
# 1  /api/v2/well_known_file_download/491384619
# 2  /api/v2/well_known_file_download/487610447
# 3  /api/v2/well_known_file_download/487361512
# 4  /api/v2/well_known_file_download/487635954
#
#                  ephys_inst_thresh_thumb_path   id
# 0  /api/v2/well_known_file_download/491376069  606
# 1  /api/v2/well_known_file_download/491384621  522
# 2  /api/v2/well_known_file_download/491377923   81
# 3  /api/v2/well_known_file_download/491767690   38
# 4  /api/v2/well_known_file_download/491376335  671
#
# [5 rows x 44 columns]

# %%
data_cre = data[data['cell_reporter_status'] == 'cre reporter positive']
data_cre_neg = data[data['cell_reporter_status'] != 'cre reporter positive']

# %%
# subsetting data - only electrophysiological component for PCA
data_sub = data_cre.iloc[:,17:27]
len(data_sub)
# Out:
# 615

# %%
# scatter plotting for exporatory visualization
scatter = pd.tools.plotting.scatter_matrix(data_sub, alpha=0.2, figsize = (32,32), diagonal = 'kde')

# %%
data_sub_wona = data_sub.fillna(0) # making NaN value to zeros - reconsider this process why not remove?
sub_np = data_sub_wona.values # numpy array
sub_np = scale(sub_np) # normalization
# check scatter plot after scaling - doesn't change data pattern
# scatter_scaled = pd.tools.plotting.scatter_matrix(pd.DataFrame(sub_np), alpha=0.2, figsize = (32,32), diagonal = 'kde')

# %%
pca = PCA(n_components = 10)
pca.fit(sub_np)
var= pca.explained_variance_ratio_
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)
print var1 #cumulative explained propotion in variation. 
plt.plot(var1)
# Out:
# [  43.05   63.2    72.3    79.62   85.18   89.91   93.59   96.18   98.38
#   100.  ]

# %%
np_pca=pca.fit_transform(sub_np)

# %%
def color_dend(dendrite): # making color code according to dendritic morphology 
    output = []
    for item in dendrite:
        if item == 'spiny':
            output = output + ['r']
        elif item == 'aspiny':
            output = output + ['g']
        else:
            output = output + ['b']
    return output
dend_c = []
dend_c = color_dend(data['tag__dendrite_type'])

plt.scatter(np_pca[:,0], np_pca[:,1], c = dend_c, alpha = .2)

# %%
def color_EI(cre_line): # making color code for excitory vs inbihitory cre line
    output = []
    for item in cre_line:
        if (item == 'Pvalb-IRES-Cre' or item == 'Sst-IRES-Cre' or
            item == 'Htr3a-Cre_NO152' or item == 'Vip-IRES-Cre' or
            item == 'Gad2-IRES-Cre'):
                output = output + ['g']
        else:
            output = output + ['r']
    return output
EI_c = []
EI_c = color_EI(data['line_name'])

plt.scatter(np_pca[:,0], np_pca[:,1], c = EI_c, alpha = .2)

# %%
def item_iden(list1, list2):
    output = []
    for i, item in enumerate(list1):
        output = output + [item == list2[i]]
    return output

def color_iden(list1, list2):
    output = []
    for i, item in enumerate(list1):
        if item == list2[i]:
            output = output + ['r']
        else:
            output = output + ['g']
    return output
dend_EI_idendity = item_iden(dend_c, EI_c)
dend_EI_idendity_c = color_iden(dend_c, EI_c)

plt.scatter(np_pca[:,0], np_pca[:,1], c = dend_EI_idendity_c, alpha = .3)

# %%
dend_c_pd = pd.DataFrame({'dend_c': dend_c})
EI_c_pd = pd.DataFrame({'EI_c': EI_c})
dend_EI_idendical_pd = pd.DataFrame({'dend_EI_idendity': dend_EI_idendity})
idendical = dend_EI_idendical_pd.join(dend_c_pd.join(EI_c_pd))

# %%
new_data = data_cre.join(idendical)
new_data
# Out:
#            line_name  specimen__id                             specimen__name  \
# 0     Scnn1a-Tg2-Cre     313862022        Scnn1a-Tg2-Cre;Ai14-167081.03.02.01
# 1     Rorb-IRES2-Cre     479508018      Rorb-IRES2-Cre-D;Ai14-196662.03.01.01
# 2    Htr3a-Cre_NO152     442627661       Htr3a-Cre_NO152;Ai14-178904.06.01.01
# 3       Cux2-CreERT2     487358945          Cux2-CreERT2;Ai14-214155.05.01.01
# 4     Scnn1a-Tg3-Cre     469803127        Scnn1a-Tg3-Cre;Ai14-180215.05.02.01
# 5     Rbp4-Cre_KL100     325941643        Rbp4-Cre_KL100;Ai14-175331.06.01.01
# 12                 right            721          Primary visual area, layer 4
# 16                  left            721          Primary visual area, layer 4
# 17                  left            721          Primary visual area, layer 4
# 18                  left            721          Primary visual area, layer 4
# 19                  left            821        Primary visual area, layer 2/3
# 20                  left            821        Primary visual area, layer 2/3
# 21                  left            721          Primary visual area, layer 4
# 22                 right            778          Primary visual area, layer 5
# 23                  left            778          Primary visual area, layer 5
# 24                 right            721          Primary visual area, layer 4
# 25                 right            778          Primary visual area, layer 5
# 26                 right            721          Primary visual area, layer 4
# 27                  left            778          Primary visual area, layer 5
# 28                 right            721          Primary visual area, layer 4
# 29                  left            778          Primary visual area, layer 5
# 30                 right            573          Lateral visual area, layer 4
# 31                  left            778          Primary visual area, layer 5
# 32                  left            721          Primary visual area, layer 4
# ..                   ...            ...                                   ...
# 658                right            778          Primary visual area, layer 5
# 659                right             41  posteromedial visual area, layer 2/3
# 660                right      312782562                Anterior area, layer 5
# 661                 left            721          Primary visual area, layer 4
# 662                 left            721          Primary visual area, layer 4
# 663                 left            721          Primary visual area, layer 4
# 664                 left            778          Primary visual area, layer 5
# 665                right            721          Primary visual area, layer 4
# 666                right            778          Primary visual area, layer 5
# 667                right            778          Primary visual area, layer 5
# 669                right            778          Primary visual area, layer 5
# 670                 left            821        Primary visual area, layer 2/3
# 671                 left            778          Primary visual area, layer 5
# 672                 left            565    posteromedial visual area, layer 5
# 673                right            778          Primary visual area, layer 5
# 674                right            778          Primary visual area, layer 5
# 675                 left      312782612           Rostrolateral area, layer 4
# 676                 left            778          Primary visual area, layer 5
# 677                 left             33         Primary visual area, layer 6a
# 678                right            778          Primary visual area, layer 5
# 679                right            721          Primary visual area, layer 4
# 680                 left            233    Anterolateral visual area, layer 5
# 681                right           1066   Anteromedial visual area, layer 2/3
# 683                 left             33         Primary visual area, layer 6a
# 684                 left            821        Primary visual area, layer 2/3
# 685                right            721          Primary visual area, layer 4
# 687                 left            778          Primary visual area, layer 5
# 688                right            721          Primary visual area, layer 4
# 689                right            721          Primary visual area, layer 4
# 691                right            805    posteromedial visual area, layer 1
#
#     structure__acronym  structure_parent__id structure_parent__acronym  \
# 0                VISp4                   385                      VISp
# 1                VISp4                   385                      VISp
# 2               VISa6a             312782546                      VISa
# 3                VISp5                   385                      VISp
# 4                VISp5                   385                      VISp
# 5               VISrl5                   417                     VISrl
# 6                VISp4                   385                      VISp
# 7                VISp4                   385                      VISp
# 8                VISp5                   385                      VISp
# 9                VISp4                   385                      VISp
# 10               VISp5                   385                      VISp
# 11               VISp4                   385                      VISp
# 12               VISp4                   385                      VISp
# 16               VISp4                   385                      VISp
# 17               VISp4                   385                      VISp
# 18               VISp4                   385                      VISp
# 19             VISp2/3                   385                      VISp
# 20             VISp2/3                   385                      VISp
# 21               VISp4                   385                      VISp
# 22               VISp5                   385                      VISp
# 23               VISp5                   385                      VISp
# 24               VISp4                   385                      VISp
# 25               VISp5                   385                      VISp
# 26               VISp4                   385                      VISp
# 27               VISp5                   385                      VISp
# 28               VISp4                   385                      VISp
# 29               VISp5                   385                      VISp
# 30               VISl4                   409                      VISl
# 31               VISp5                   385                      VISp
# 32               VISp4                   385                      VISp
# ..                 ...                   ...                       ...
# 658              VISp5                   385                      VISp
# 659           VISpm2/3                   533                     VISpm
# 660              VISa5             312782546                      VISa
# 661              VISp4                   385                      VISp
# 662              VISp4                   385                      VISp
# 663              VISp4                   385                      VISp
# 664              VISp5                   385                      VISp
# 665              VISp4                   385                      VISp
# 666              VISp5                   385                      VISp
# 667              VISp5                   385                      VISp
# 669              VISp5                   385                      VISp
# 670            VISp2/3                   385                      VISp
# 671              VISp5                   385                      VISp
# 672             VISpm5                   533                     VISpm
# 673              VISp5                   385                      VISp
# 674              VISp5                   385                      VISp
# 675             VISrl4                   417                     VISrl
# 676              VISp5                   385                      VISp
# 677             VISp6a                   385                      VISp
# 678              VISp5                   385                      VISp
# 679              VISp4                   385                      VISp
# 680             VISal5                   402                     VISal
# 681           VISam2/3                   394                     VISam
# 683             VISp6a                   385                      VISp
# 684            VISp2/3                   385                      VISp
# 685              VISp4                   385                      VISp
# 687              VISp5                   385                      VISp
# 688              VISp4                   385                      VISp
# 689              VISp4                   385                      VISp
# 691             VISpm1                   533                     VISpm
#
#     structure__layer  ...   m__biophys_all_active  tag__apical  \
# 0                  4  ...                       0       intact
# 1                  4  ...                       0       intact
# 2                 6a  ...                       0          NaN
# 3                  5  ...                       0       intact
# 4                  5  ...                       0       intact
# 5                  5  ...                       0       intact
# 6                  4  ...                       0       intact
# 7                  4  ...                       0       intact
# 8                  5  ...                       0       intact
# 9                  4  ...                       0       intact
# 10                 5  ...                       0       intact
# 11                 4  ...                       1       intact
# 12                 4  ...                       0       intact
# 16                 4  ...                       0       intact
# 17                 4  ...                       0       intact
# 18                 4  ...                       0       intact
# 19            02-Mar  ...                       1          NaN
# 20            02-Mar  ...                       1          NaN
# 21                 4  ...                       0       intact
# 22                 5  ...                       0       intact
# 23                 5  ...                       0       intact
# 24                 4  ...                       0       intact
# 25                 5  ...                       0       intact
# 26                 4  ...                       0       intact
# 27                 5  ...                       1       intact
# 28                 4  ...                       0       intact
# 29                 5  ...                       0       intact
# 30                 4  ...                       0       intact
# 31                 5  ...                       0       intact
# 32                 4  ...                       0       intact
# ..               ...  ...                     ...          ...
# 658                5  ...                       0          NaN
# 659           02-Mar  ...                       0          NaN
# 660                5  ...                       0          NaN
# 661                4  ...                       1          NaN
# 662                4  ...                       0          NaN
# 663                4  ...                       0          NaN
# 664                5  ...                       0          NaN
# 665                4  ...                       0          NaN
# 666                5  ...                       0          NaN
# 667                5  ...                       0          NaN
# 669                5  ...                       0          NaN
# 670           02-Mar  ...                       0          NaN
# 671                5  ...                       0          NaN
# 672                5  ...                       0          NaN
# 673                5  ...                       0          NaN
# 674                5  ...                       0          NaN
# 675                4  ...                       0          NaN
# 676                5  ...                       0          NaN
# 677               6a  ...                       0          NaN
# 678                5  ...                       0          NaN
# 679                4  ...                       0          NaN
# 680                5  ...                       1          NaN
# 681           02-Mar  ...                       0          NaN
# 683               6a  ...                       0          NaN
# 684           02-Mar  ...                       0          NaN
# 685                4  ...                       0          NaN
# 687                5  ...                       0          NaN
# 688                4  ...                       0          NaN
# 689                4  ...                       0          NaN
# 691                1  ...                       0          NaN
#
#      tag__dendrite_type                            morph_thumb_path  \
# 0                 spiny  /api/v2/well_known_file_download/487659609
# 1                 spiny                                         NaN
# 2                aspiny                                         NaN
# 3                 spiny                                         NaN
# 4                 spiny                                         NaN
# 5                 spiny  /api/v2/well_known_file_download/487659313
# 6                 spiny                                         NaN
# 7                 spiny  /api/v2/well_known_file_download/508279122
# 8                 spiny                                         NaN
# 9                 spiny                                         NaN
# 10                spiny  /api/v2/well_known_file_download/487662286
# 11                spiny  /api/v2/well_known_file_download/487661798
# 12                spiny  /api/v2/well_known_file_download/496139468
# 16                spiny                                         NaN
# 17                spiny  /api/v2/well_known_file_download/512328756
# 18                spiny  /api/v2/well_known_file_download/516608131
# 19               aspiny  /api/v2/well_known_file_download/487661102
# 20               aspiny  /api/v2/well_known_file_download/487660871
# 21                spiny  /api/v2/well_known_file_download/508279128
# 22                spiny  /api/v2/well_known_file_download/508279173
# 23                spiny                                         NaN
# 24                spiny  /api/v2/well_known_file_download/487661716
# 25                spiny                                         NaN
# 26                spiny                                         NaN
# 27                spiny  /api/v2/well_known_file_download/487660875
# 28                spiny  /api/v2/well_known_file_download/505206469
# 29                spiny                                         NaN
# 30                spiny                                         NaN
# 31                spiny  /api/v2/well_known_file_download/487660858
# 32                spiny                                         NaN
# ..                  ...                                         ...
# 658              aspiny                                         NaN
# 659              aspiny  /api/v2/well_known_file_download/501086571
# 660              aspiny                                         NaN
# 661              aspiny  /api/v2/well_known_file_download/496357032
# 662              aspiny                                         NaN
# 663              aspiny                                         NaN
# 664              aspiny                                         NaN
# 665              aspiny                                         NaN
# 666              aspiny                                         NaN
# 667              aspiny  /api/v2/well_known_file_download/487660846
# 669              aspiny  /api/v2/well_known_file_download/489405463
# 670              aspiny                                         NaN
# 671              aspiny                                         NaN
# 672              aspiny                                         NaN
# 673              aspiny                                         NaN
# 674              aspiny                                         NaN
# 675              aspiny                                         NaN
# 676              aspiny                                         NaN
# 677              aspiny                                         NaN
# 678              aspiny                                         NaN
# 679              aspiny  /api/v2/well_known_file_download/508278327
# 680              aspiny  /api/v2/well_known_file_download/487659410
# 681              aspiny                                         NaN
# 683              aspiny                                         NaN
# 684              aspiny                                         NaN
# 685              aspiny                                         NaN
# 687              aspiny                                         NaN
# 688              aspiny                                         NaN
# 689              aspiny                                         NaN
# 691              aspiny                                         NaN
#
#                                ephys_thumb_path  \
# 0    /api/v2/well_known_file_download/487623088
# 1    /api/v2/well_known_file_download/491384619
# 2    /api/v2/well_known_file_download/487610447
# 3    /api/v2/well_known_file_download/487361512
# 4    /api/v2/well_known_file_download/487635954
# 5    /api/v2/well_known_file_download/487619287
# 6    /api/v2/well_known_file_download/483108650
# 7    /api/v2/well_known_file_download/486561182
# 8    /api/v2/well_known_file_download/490171101
# 9    /api/v2/well_known_file_download/484629158
# 10   /api/v2/well_known_file_download/483108395
# 11   /api/v2/well_known_file_download/487633010
# 12   /api/v2/well_known_file_download/485856738
# 16   /api/v2/well_known_file_download/511602516
# 17   /api/v2/well_known_file_download/485886177
# 18   /api/v2/well_known_file_download/486240027
# 19   /api/v2/well_known_file_download/487611643
# 20   /api/v2/well_known_file_download/487610194
# 21   /api/v2/well_known_file_download/491376859
# 22   /api/v2/well_known_file_download/485860065
# 23   /api/v2/well_known_file_download/512475593
# 24   /api/v2/well_known_file_download/487629700
# 25   /api/v2/well_known_file_download/489888164
# 26   /api/v2/well_known_file_download/485510624
# 27   /api/v2/well_known_file_download/487622116
# 28   /api/v2/well_known_file_download/488121184
# 29   /api/v2/well_known_file_download/486503168
# 30   /api/v2/well_known_file_download/512473893
# 31   /api/v2/well_known_file_download/487624978
# 32   /api/v2/well_known_file_download/511624248
# ..                                          ...
# 658  /api/v2/well_known_file_download/487636193
# 659  /api/v2/well_known_file_download/488502713
# 660  /api/v2/well_known_file_download/487616528
# 661  /api/v2/well_known_file_download/487667788
# 662  /api/v2/well_known_file_download/514803710
# 663  /api/v2/well_known_file_download/488273495
# 664  /api/v2/well_known_file_download/487627276
# 665  /api/v2/well_known_file_download/491090559
# 666  /api/v2/well_known_file_download/488502547
# 667  /api/v2/well_known_file_download/487620885
# 669  /api/v2/well_known_file_download/485479568
# 670  /api/v2/well_known_file_download/483151997
# 671  /api/v2/well_known_file_download/484746029
# 672  /api/v2/well_known_file_download/490388645
# 673  /api/v2/well_known_file_download/483154144
# 674  /api/v2/well_known_file_download/491380587
# 675  /api/v2/well_known_file_download/483154446
# 676  /api/v2/well_known_file_download/487638509
# 677  /api/v2/well_known_file_download/490405554
# 678  /api/v2/well_known_file_download/485475753
# 679  /api/v2/well_known_file_download/486897824
# 680  /api/v2/well_known_file_download/487611297
# 681  /api/v2/well_known_file_download/487628001
# 683  /api/v2/well_known_file_download/487334182
# 684  /api/v2/well_known_file_download/491380742
# 685  /api/v2/well_known_file_download/486781389
# 687  /api/v2/well_known_file_download/487579174
# 688  /api/v2/well_known_file_download/491088471
# 689  /api/v2/well_known_file_download/484746165
# 691  /api/v2/well_known_file_download/485054850
#
#                    ephys_inst_thresh_thumb_path   id  dend_EI_idendity  \
# 0    /api/v2/well_known_file_download/491376069  606              True
# 1    /api/v2/well_known_file_download/491384621  522              True
# 2    /api/v2/well_known_file_download/491377923   81              True
# 3    /api/v2/well_known_file_download/491767690   38              True
# 4    /api/v2/well_known_file_download/491376335  671              True
# 5    /api/v2/well_known_file_download/491376039  401              True
# 6    /api/v2/well_known_file_download/491377251  537              True
# 7    /api/v2/well_known_file_download/491383715   32              True
# 8    /api/v2/well_known_file_download/491611574   51              True
# 9    /api/v2/well_known_file_download/491384547  194              True
# 10   /api/v2/well_known_file_download/491383093  529              True
# 11   /api/v2/well_known_file_download/491383320  682              True
# 12   /api/v2/well_known_file_download/491384101  428              True
# 16   /api/v2/well_known_file_download/511602518   57              True
# 17   /api/v2/well_known_file_download/491384401  560              True
# 18   /api/v2/well_known_file_download/491377321   31              True
# 19   /api/v2/well_known_file_download/491381642   82              True
# 20   /api/v2/well_known_file_download/491383420   84              True
# 21   /api/v2/well_known_file_download/491376861  501              True
# 22   /api/v2/well_known_file_download/491378448  430              True
# 23   /api/v2/well_known_file_download/512475595    5              True
# 24   /api/v2/well_known_file_download/491381939  490              True
# 25   /api/v2/well_known_file_download/491529750   49              True
# 26   /api/v2/well_known_file_download/491382284    8              True
# 27   /api/v2/well_known_file_download/491382594  648              True
# 28   /api/v2/well_known_file_download/491377199  443              True
# 29   /api/v2/well_known_file_download/491383982  565              True
# 30   /api/v2/well_known_file_download/512473895  600              True
# 31   /api/v2/well_known_file_download/491380421  404              True
# 32   /api/v2/well_known_file_download/511624250  598              True
# ..                                          ...  ...               ...
# 658  /api/v2/well_known_file_download/491381567  270              True
# 659  /api/v2/well_known_file_download/491384758  380              True
# 660  /api/v2/well_known_file_download/491382778  260              True
# 661  /api/v2/well_known_file_download/491377670  372              True
# 662  /api/v2/well_known_file_download/514803712  394              True
# 663  /api/v2/well_known_file_download/491378724  375              True
# 664  /api/v2/well_known_file_download/491384082  296              True
# 665  /api/v2/well_known_file_download/491765296  393              True
# 666  /api/v2/well_known_file_download/491378852  381              True
# 667  /api/v2/well_known_file_download/491382970  309              True
# 669  /api/v2/well_known_file_download/491383944  341              True
# 670  /api/v2/well_known_file_download/491378315  335              True
# 671  /api/v2/well_known_file_download/491383119  347              True
# 672  /api/v2/well_known_file_download/491623327  390              True
# 673  /api/v2/well_known_file_download/491378858  340              True
# 674  /api/v2/well_known_file_download/491380589  776              True
# 675  /api/v2/well_known_file_download/491380729  289              True
# 676  /api/v2/well_known_file_download/491380675  304              True
# 677  /api/v2/well_known_file_download/491623357  391              True
# 678  /api/v2/well_known_file_download/491382259  123              True
# 679  /api/v2/well_known_file_download/491377506  362              True
# 680  /api/v2/well_known_file_download/491382792   61              True
# 681  /api/v2/well_known_file_download/491380703  295              True
# 683  /api/v2/well_known_file_download/491378524  363              True
# 684  /api/v2/well_known_file_download/491380744  318              True
# 685  /api/v2/well_known_file_download/491376870  360              True
# 687  /api/v2/well_known_file_download/491378489  368              True
# 688  /api/v2/well_known_file_download/491762149  392              True
# 689  /api/v2/well_known_file_download/491376528  348              True
# 691  /api/v2/well_known_file_download/491384231  350              True
#
#      dend_c  EI_c
# 0         r     r
# 1         r     r
# 2         g     g
# 3         r     r
# 4         r     r
# 5         r     r
# 6         r     r
# 7         r     r
# 8         r     r
# 9         r     r
# 10        r     r
# 11        r     r
# 12        r     r
# 16        r     r
# 17        r     r
# 18        r     r
# 19        g     g
# 20        g     g
# 21        r     r
# 22        r     r
# 23        r     r
# 24        r     r
# 25        r     r
# 26        r     r
# 27        r     r
# 28        r     r
# 29        r     r
# 30        r     r
# 31        r     r
# 32        r     r
# ..      ...   ...
# 658       g     g
# 659       g     g
# 660       g     g
# 661       g     g
# 662       g     g
# 663       g     g
# 664       g     g
# 665       g     g
# 666       g     g
# 667       g     g
# 669       g     g
# 670       g     g
# 671       g     g
# 672       g     g
# 673       g     g
# 674       g     g
# 675       g     g
# 676       g     g
# 677       g     g
# 678       g     g
# 679       g     g
# 680       g     g
# 681       g     g
# 683       g     g
# 684       g     g
# 685       g     g
# 687       g     g
# 688       g     g
# 689       g     g
# 691       g     g
#
# [615 rows x 47 columns]

# %%
dend_EI_diff = new_data[new_data['dend_EI_idendity'] == 0]
len(dend_EI_diff)
# Out:
# 20

# %%
line_name_freq = pd.DataFrame(dend_EI_diff['line_name'].value_counts())
line_name_freq
# Out:
#                  line_name
# Sst-IRES-Cre            10
# Rorb-IRES2-Cre           4
# Nr5a1-Cre                3
# Htr3a-Cre_NO152          2
# Scnn1a-Tg3-Cre           1

# %%
EI_freq = pd.DataFrame(dend_EI_diff['EI_c'].value_counts())
EI_freq # r = excitatory, g = inhibitory
# Out:
#    EI_c
# g    12
# r     8

# %%
dend_freq = pd.DataFrame(dend_EI_diff['dend_c'].value_counts())
dend_freq # r = spiny, g = aspiny, b = sparsely spiny
# Out:
#    dend_c
# b       9
# g       8
# r       3

# %%
cre_freq = pd.DataFrame(dend_EI_diff['cell_reporter_status'].value_counts())
cre_freq
# Out:
#                        cell_reporter_status
# cre reporter positive                    20

# %%
dend_EI_diff.loc[:,['line_name','cell_reporter_status','dend_c', 'EI_c']]
# Out:
#            line_name   cell_reporter_status dend_c EI_c
# 91      Sst-IRES-Cre  cre reporter positive      r    g
# 92    Rorb-IRES2-Cre  cre reporter positive      g    r
# 98         Nr5a1-Cre  cre reporter positive      g    r
# 163   Rorb-IRES2-Cre  cre reporter positive      g    r
# 242  Htr3a-Cre_NO152  cre reporter positive      r    g
# 252   Rorb-IRES2-Cre  cre reporter positive      g    r
# 263  Htr3a-Cre_NO152  cre reporter positive      r    g
# 292   Rorb-IRES2-Cre  cre reporter positive      g    r
# 297        Nr5a1-Cre  cre reporter positive      g    r
# 370   Scnn1a-Tg3-Cre  cre reporter positive      g    r
# 374     Sst-IRES-Cre  cre reporter positive      b    g
# 379     Sst-IRES-Cre  cre reporter positive      b    g
# 389     Sst-IRES-Cre  cre reporter positive      b    g
# 410     Sst-IRES-Cre  cre reporter positive      b    g
# 429     Sst-IRES-Cre  cre reporter positive      b    g
# 437     Sst-IRES-Cre  cre reporter positive      b    g
# 478        Nr5a1-Cre  cre reporter positive      g    r
# 494     Sst-IRES-Cre  cre reporter positive      b    g
# 509     Sst-IRES-Cre  cre reporter positive      b    g
# 510     Sst-IRES-Cre  cre reporter positive      b    g
